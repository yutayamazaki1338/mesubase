# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests



def page_data_make(base_url):
    res = requests.get(base_url)

    #建物名
    soup = BeautifulSoup(res.text)
    a = soup.select("h2.property_inner-title > a")
    

    for i in range(len(a)):
        an = a[i].get_text().split()
        A.append(an[0])



    c = soup.select("td.detailbox-property-col > div")
    C = []

    for i in range(len(c)):
        cn = c[i].get_text().split()
        C.append(cn[0])
    

    d=0
    A1=[]
    B1=[]
    for a in c:
        if d !=11:
            x = a.get_text().split()
            if x != ['※定期借家']:
                A1.append(a.get_text().split())
                d += 1
            
               
            
        elif d == 11:
            B1.append(A1)
            A1 = []
            x = a.get_text().split()
            if x != ['※定期借家']:
                A1.append(x)
                d = 1
            
            
                
            
    B1.append(A1) #調整用 
    



    for i in range(len(B1)):
        yatin.append(B1[i][0][0])
        kanri.append(B1[i][1][1])
        sikikin.append(B1[i][2][0])
        reikinn.append(B1[i][3][0])
        hosyoukin.append(B1[i][4][1])
        sikibiki.append(B1[i][5][1])
        madori.append(B1[i][6][0])
        menseki.append(B1[i][7][0])
        hougaku.append(B1[i][8][0])
        type_st.append(B1[i][9][0])
        tiku.append(B1[i][10][0])

    #住所
    d = soup.select("td.detailbox-property-col")
    D = []
    
    for i in range(len(d)):
        dn = d[i].get_text().split()
        D.append(dn[0])

    A2=[]
    B2=[]
    d1 = 0
    for a in D:
        if d1 !=5:
            A2.append(a)
            d1 += 1
        elif d1 == 5:
            B2.append(A2)
            A2 = []
            A2.append(a)
            d1 = 1
    B2.append(A2)
    
    
    for st in range(len(B2)):
        zyuusyo.append(B2[st][4])
    
    time.sleep(1)
    
    #アクセス
    d = soup.select("div.detailnote-box")
    for r in range(len(d)):
        if r % 2 == 0:
            dn = d[r].get_text().split()
            access.append(dn)
    
def output_data():
    output_data = pd.DataFrame({"建物名":A, "家賃":yatin, "管理費":kanri, "敷金":sikikin, "礼金":reikinn,
                                 "保証金":hosyoukin, "敷引・償却":sikibiki, "間取り":madori, "面積":menseki,
                                 "方角":hougaku, "構造":type_st, "築年数":tiku, "住所":zyuusyo,"アクセス":access})
    return output_data

#次のページを探すリンク
def next_page_link():
    res = requests.get(base_url)
    soup = BeautifulSoup(res.text)

    A6 = soup.select("p.pagination-parts > a")
    R = open_url + A6[0]["href"]#次のページのリンク
    return R

chiyoda = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13101&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
chuou = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13102&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
minato = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13103&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
sinzyuku = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13104&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
bunkyou = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13105&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
sibuya = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13113&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
daitou = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13106&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
sumida = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13107&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
koutou = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13108&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
arakawa = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13118&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
adachi = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13121&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
katusika = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13122&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
edogawa = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13123&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
sinagawa = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13109&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
meguro = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13110&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
oota = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13111&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
setagaya = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13112&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
nakano = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13114&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
suginami = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13115&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
nerima = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13120&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
toyosima = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13116&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
kita = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13117&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"
itabashi = "https://suumo.jp/jj/chintai/ichiran/FR301FC005/?ar=030&bs=040&ta=13&sc=13119&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&po2=99&pc=100"

Tokyo_23 = [chiyoda, chuou, minato, sinzyuku, bunkyou, sibuya, daitou, sumida, koutou, arakawa, adachi, katusika, edogawa,
            sinagawa, meguro, oota, setagaya, nakano, suginami, nerima, toyosima, kita, itabashi]

pages = [124, 268, 447, 415, 189, 346, 280, 273, 380, 99, 281, 171, 253, 424, 236, 452, 564, 251, 429, 389, 280, 324, 351]

A = []
yatin = []
kanri = []
sikikin = []
reikinn = []
hosyoukin = []
sikibiki = []
madori = []
menseki = []
hougaku = []
type_st = []
tiku = []
zyuusyo = []
access = []


open_url="https://suumo.jp"#飛ぶのに必要なリンクとくっつける

# %%
for t in range(23):
    base_url = Tokyo_23[t]
    page = 0
    while True:
        
        if page != pages[t]:
            page_data_make(base_url)
            try:
                base_url = next_page_link()
                page += 1
                print(page,len(A))
            except:
                break
        else:
            break
    print(t+1,"個のデータが集計完了")
    
out_put_data = output_data()
out_put_data.to_csv(r"C:\Users\Yuta_yamazaki\Desktop\train_add.csv")
# Out:
# 1 100
# 2 200
# 3 300
# 4 400
# 5 500
# 6 600
# 7 700
# 8 800
# 9 900
# 10 1000
# 11 1100
# 12 1200
# 13 1300
# 14 1400
# 15 1500
# 16 1600
# 17 1700
# 18 1800
# 19 1900
# 20 2000
# 21 2100
# 22 2200
# 23 2300
# 24 2400
# 25 2500
# 26 2600
# 27 2700
# 28 2800
# 29 2900
# 30 3000
# 31 3100
# 32 3200
# 33 3300
# 34 3400
# 35 3500
# 36 3600
# 37 3700
# 38 3800
# 39 3900
# 40 4000
# 41 4100
# 42 4200
# 43 4300
# 44 4400
# 45 4500
# 46 4600
# 47 4700
# 48 4800
# 49 4900
# 50 5000
# 51 5100
# 52 5200
# 53 5300
# 54 5400
# 55 5500
# 56 5600
# 57 5700
# 58 5800
# 59 5900
# 60 6000
# 61 6100
# 62 6200
# 63 6300
# 64 6400
# 65 6500
# 66 6600
# 67 6700
# 68 6800
# 69 6900
# 70 7000
# 71 7100
# 72 7200
# 73 7300
# 74 7400
# 75 7500
# 76 7600
# 77 7700
# 78 7800
# 79 7900
# 80 8000
# 81 8100
# 82 8200
# 83 8300
# 84 8400
# 85 8500
# 86 8600
# 87 8700
# 88 8800
# 89 8900
# 90 9000
# 91 9100
# 92 9200
# 93 9300
# 94 9400
# 95 9500
# 96 9600
# 97 9700
# 98 9800
# 99 9900
# 100 10000
# 101 10100
# ...

# %%
#試験運用
for t in range(23):
    base_url = Tokyo_23[t]
    page = 0
    while True:
        
        if page != 2:
            page_data_make(base_url)
            try:
                base_url = next_page_link()
                page += 1
                print(page,len(A))
            except:
                break
        else:
            break
    print(t+1,"個のデータが集計完了")
    
out_put_data = output_data()
out_put_data.to_csv(r"C:\Users\Yuta_yamazaki\Desktop\train_add.csv")
# Out:
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 1 100
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 2 200
# 1 個のデータが集計完了
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 1 300
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 2 400
# 2 個のデータが集計完了
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 1 500
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 2 600
# 3 個のデータが集計完了
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 1 700
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# 定期借家が紛れ込んでます。除外しました。
# データ数は 100
# 2 800
# ...

# %%
len(A)
# Out:
# 78200
